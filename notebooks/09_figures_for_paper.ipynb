# %% [markdown]
# # 09 — Paper figures
# Every figure the paper needs, generated from `results/` CSVs, saved as PDF (vector) to `figures/`. One cell per figure; figure numbers match the manuscript.
#
# Planned: F1 frontier per corpus · detection-delay boxplots · decision timeline for one illustrative stream · cost-grid sensitivity heatmap · H4 equivalence plot.

# %%
# --- Colab bootstrap (same cell in every notebook) ---
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/sandesh20lamichhane/when-should-ids-adapt.git /content/repo 2>/dev/null || (cd /content/repo && git pull)
import sys; sys.path.insert(0, '/content/repo')

from src.config import CFG, git_hash, results_path
CFG.make_dirs()
print('commit:', git_hash())

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.family': 'serif', 'font.size': 9,
                     'figure.dpi': 150, 'savefig.bbox': 'tight'})
# TODO: figures - always plt.savefig(CFG.FIGURES / 'fig_X_name.pdf')
