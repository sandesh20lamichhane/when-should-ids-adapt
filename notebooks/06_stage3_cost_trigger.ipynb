# %% [markdown]
# # 06 — Stage 3: cost-aware trigger dry run
# Wires Stage 1 + Stage 2 outputs into `trigger.decide` over the COST_GRID and verifies decision behaviour on calibration data (should be ~all 'monitor'). No evaluation stream contact.

# %%
# --- Colab bootstrap (same cell in every notebook) ---
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/sandesh20lamichhane/when-should-ids-adapt.git /content/repo 2>/dev/null || (cd /content/repo && git pull)
import sys; sys.path.insert(0, '/content/repo')

from src.config import CFG, git_hash, results_path
CFG.make_dirs()
print('commit:', git_hash())

# %%
from src.trigger import CostParams, COST_GRID, decide, hybrid_acquisition
print(f'{len(COST_GRID)} cost-grid points (frozen in src/trigger.py)')
# TODO: replay calibration windows through the full 3-stage path and log
# decision rates per grid point -> results/ dry-run CSV
